# %% [markdown]
# # CPC/IPC Klassen-Statistik mit mehr Details

# %%
# import module with utility functions
import klassen_stats

# %%
# read input from CSV data file
data = klassen_stats.ReadCSVFile( '../csv/details.csv' )

# %%
# show file contents
print( data )
# Out:
# [['Aktennummer', 'Klassen', '', '', ''], ['A 1/2019', 'G06F3/21', 'H04M5/10', '', ''], ['GM 2/2019', 'G16H10/10', 'G16H10/20', 'G16H10/40', ''], ['KN 3/2019', 'G06T3/455', 'G06Q10/035', 'A60R1/12', ''], ['PCT 4/2019', 'G06F3/21', 'G06N5/00', 'B23C45/67', 'A47J9/00'], ['EMR 5/2019', 'G06T3/45', 'G01N1/23', 'G06F3/21', '']]

# %%
# generate statistics
stat = klassen_stats.GetCounts( data )

# %%
# show statistics overview in table form
print( stat )
# Out:
# [['A47J9/00' '1']
#  ['A60R1/12' '1']
#  ['B23C45/67' '1']
#  ['G01N1/23' '1']
#  ['G06F3/21' '3']
#  ['G06N5/00' '1']
#  ['G06Q10/035' '1']
#  ['G06T3/45' '1']
#  ['G06T3/455' '1']
#  ['G16H10/10' '1']
#  ['G16H10/20' '1']
#  ['G16H10/40' '1']
#  ['H04M5/10' '1']]

# %%
# show bar chart
klassen_stats.MakePlot( stat )
